# %%
import cv2

# %%
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
from deepface import DeepFace

# %%
import matplotlib.pyplot as plt
import matplotlib.image as img

# %%
img = cv2.imread('happy_face.jpeg') #happy

# %%
plt.imshow(img)

# %%
pre = DeepFace.analyze(img)
# Out:
# 24-01-26 15:10:16 - age_model_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/age_model_weights.h5
# To: C:\Users\HP\.deepface\weights\age_model_weights.h5
# 100%|████████████████████████████████████████████████████████████████████████████████| 539M/539M [12:40<00:00, 708kB/s]
# 24-01-26 15:23:04 - gender_model_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/gender_model_weights.h5
# To: C:\Users\HP\.deepface\weights\gender_model_weights.h5
# 100%|███████████████████████████████████████████████████████████████████████████████| 537M/537M [08:34<00:00, 1.04MB/s]
# 24-01-26 15:31:49 - race_model_single_batch.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/race_model_single_batch.h5
# To: C:\Users\HP\.deepface\weights\race_model_single_batch.h5
# ...

# %%
pre
# Out:
# [{'emotion': {'angry': 1.1593557711075952e-09,
#    'disgust': 8.568514279182204e-11,
#    'fear': 6.0106799537607e-06,
#    'happy': 99.99818801879883,
#    'sad': 2.7839034189014455e-06,
#    'surprise': 1.8678190105703152e-07,
#    'neutral': 0.001807545413612388},
#   'dominant_emotion': 'happy',
#   'region': {'x': 92, 'y': 74, 'w': 433, 'h': 433},
#   'face_confidence': 8.81439003086416,
#   'age': 25,
#   'gender': {'Woman': 15.438447892665863, 'Man': 84.56155061721802},
#   'dominant_gender': 'Man',
#   'race': {'asian': 27.43234634399414,
#    'indian': 3.4916575998067856,
#    'black': 2.6540055871009827,
#    'white': 29.585233330726624,
#    'middle eastern': 7.26359561085701,
#    'latino hispanic': 29.573160409927368},
#   'dominant_race': 'white'}]

# %%
pre1= pre[0]

# %%
fc = cv2.CascadeClassifier(cv2.data.haarcascades+'haarcascade_frontalface_default.xml')

# %%
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
faces = fc.detectMultiScale(gray,1.1,4)
#drawing rectangle around the face
for(x,y,w,h) in faces:
    cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,0),2)

# %%
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
font = cv2.FONT_HERSHEY_SIMPLEX

cv2.putText(img,pre1['dominant_emotion'],(0,50),font,1,(255,0,0),2,cv2.LINE_4)
# Out:
# array([[[115, 105, 105],
#         [120, 110, 110],
#         [118, 108, 108],
#         ...,
#         [125, 113, 111],
#         [128, 116, 114],
#         [129, 117, 115]],
#
#        [[114, 104, 104],
#         [119, 109, 109],
#         [119, 109, 109],
#         ...,
#         [129, 117, 115],
#         [130, 118, 116],
#         [130, 118, 116]],
#
#        [[111, 101, 101],
#         [116, 106, 106],
#         [115, 107, 107],
#         ...,
#         [126, 117, 114],
#         [125, 116, 113],
#         [124, 115, 112]],
#
#        ...,
#
#        [[155, 148, 145],
#         [155, 148, 145],
#         [156, 149, 146],
#         ...,
#         [161, 149, 145],
#         [163, 151, 147],
#         [166, 154, 150]],
#
#        [[157, 150, 147],
#         [157, 150, 147],
#         [158, 151, 148],
#         ...,
#         [163, 151, 147],
#         [163, 151, 147],
#         [164, 152, 148]],
#
#        [[157, 150, 147],
#         [158, 151, 148],
#         [158, 151, 148],
# ...

# %%
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
img = cv2.imread('sad_face.jpg') #sad

# %%
plt.imshow(img)

# %%
pre = DeepFace.analyze(img)
# Out:
# Action: race: 100%|██████████████████████████████████████████████████████████████████████| 4/4 [00:02<00:00,  1.69it/s]

# %%
pre
# Out:
# [{'emotion': {'angry': 28.152906894683838,
#    'disgust': 0.07459300104528666,
#    'fear': 7.3433734476566315,
#    'happy': 0.008814223838271573,
#    'sad': 51.542723178863525,
#    'surprise': 0.30702913645654917,
#    'neutral': 12.570556998252869},
#   'dominant_emotion': 'sad',
#   'region': {'x': 199, 'y': 109, 'w': 212, 'h': 212},
#   'face_confidence': 9.588107048009988,
#   'age': 29,
#   'gender': {'Woman': 0.0006520302122225985, 'Man': 99.99934434890747},
#   'dominant_gender': 'Man',
#   'race': {'asian': 0.015662652731407434,
#    'indian': 5.154300108551979,
#    'black': 0.01863178185885772,
#    'white': 12.133599072694778,
#    'middle eastern': 75.85936188697815,
#    'latino hispanic': 6.818448007106781},
#   'dominant_race': 'middle eastern'}]

# %%
pre1= pre[0]

# %%
fc = cv2.CascadeClassifier(cv2.data.haarcascades+'haarcascade_frontalface_default.xml')

# %%
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
faces = fc.detectMultiScale(gray,1.1,4)
#drawing rectangle around the face
for(x,y,w,h) in faces:
    cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,0),2)

# %%
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
font = cv2.FONT_HERSHEY_SIMPLEX

cv2.putText(img,pre1['dominant_emotion'],(0,50),font,1,(255,0,0),2,cv2.LINE_4)
# Out:
# array([[[127, 133, 141],
#         [127, 133, 141],
#         [127, 133, 141],
#         ...,
#         [172, 172, 174],
#         [175, 174, 176],
#         [173, 173, 175]],
#
#        [[127, 133, 141],
#         [127, 133, 141],
#         [127, 133, 141],
#         ...,
#         [173, 173, 175],
#         [175, 174, 176],
#         [172, 172, 174]],
#
#        [[127, 133, 141],
#         [127, 133, 141],
#         [127, 133, 141],
#         ...,
#         [173, 173, 175],
#         [173, 173, 175],
#         [170, 169, 172]],
#
#        ...,
#
#        [[127, 133, 141],
#         [129, 136, 144],
#         [127, 133, 141],
#         ...,
#         [164, 165, 170],
#         [161, 164, 169],
#         [160, 163, 167]],
#
#        [[126, 132, 140],
#         [128, 135, 143],
#         [126, 132, 140],
#         ...,
#         [164, 165, 170],
#         [161, 164, 169],
#         [160, 163, 167]],
#
#        [[127, 133, 141],
#         [126, 132, 140],
#         [126, 132, 140],
# ...

# %%
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
img = cv2.imread('fear_face.jpg') #fear

# %%
plt.imshow(img)

# %%
pre = DeepFace.analyze(img)
# Out:
# Action: race: 100%|██████████████████████████████████████████████████████████████████████| 4/4 [00:02<00:00,  1.91it/s]

# %%
pre
# Out:
# [{'emotion': {'angry': 3.501249804943823,
#    'disgust': 0.011691205206816768,
#    'fear': 8.76514881668701,
#    'happy': 0.03642728700051761,
#    'sad': 0.7398324136635764,
#    'surprise': 86.77824893257035,
#    'neutral': 0.16739686585329583},
#   'dominant_emotion': 'surprise',
#   'region': {'x': 195, 'y': 102, 'w': 215, 'h': 215},
#   'face_confidence': 8.940766006417107,
#   'age': 31,
#   'gender': {'Woman': 99.99837875366211, 'Man': 0.001619585782464128},
#   'dominant_gender': 'Woman',
#   'race': {'asian': 90.58068990707397,
#    'indian': 0.1814984017983079,
#    'black': 0.026835990138351917,
#    'white': 6.296738237142563,
#    'middle eastern': 0.14101490378379822,
#    'latino hispanic': 2.7732323855161667},
#   'dominant_race': 'asian'}]

# %%
pre1=pre[0]

# %%
fc = cv2.CascadeClassifier(cv2.data.haarcascades+'haarcascade_frontalface_default.xml')

# %%
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
faces = fc.detectMultiScale(gray,1.1,4)
#drawing rectangle around the face
for(x,y,w,h) in faces:
    cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,0),2)

# %%
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
font = cv2.FONT_HERSHEY_SIMPLEX

cv2.putText(img,pre1['dominant_emotion'],(0,50),font,1,(255,0,0),2,cv2.LINE_4)
# Out:
# array([[[213, 217, 218],
#         [213, 217, 218],
#         [213, 217, 218],
#         ...,
#         [213, 217, 218],
#         [213, 217, 218],
#         [213, 217, 218]],
#
#        [[213, 217, 218],
#         [213, 217, 218],
#         [213, 217, 218],
#         ...,
#         [213, 217, 218],
#         [213, 217, 218],
#         [213, 217, 218]],
#
#        [[213, 217, 218],
#         [213, 217, 218],
#         [213, 217, 218],
#         ...,
#         [213, 217, 218],
#         [213, 217, 218],
#         [213, 217, 218]],
#
#        ...,
#
#        [[213, 217, 218],
#         [213, 217, 218],
#         [213, 217, 218],
#         ...,
#         [213, 217, 218],
#         [213, 217, 218],
#         [213, 217, 218]],
#
#        [[213, 217, 218],
#         [213, 217, 218],
#         [213, 217, 218],
#         ...,
#         [213, 217, 218],
#         [213, 217, 218],
#         [213, 217, 218]],
#
#        [[213, 217, 218],
#         [213, 217, 218],
#         [213, 217, 218],
# ...

# %%
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
img = cv2.imread('normal_face.jpg') #normal

# %%
plt.imshow(img)

# %%
pre = DeepFace.analyze(img)
# Out:
# Action: race: 100%|██████████████████████████████████████████████████████████████████████| 4/4 [00:02<00:00,  1.77it/s]

# %%
pre
# Out:
# [{'emotion': {'angry': 0.02449072053880069,
#    'disgust': 6.405289956350006e-12,
#    'fear': 0.017598903972031413,
#    'happy': 0.00035976547549361406,
#    'sad': 0.31476846909633094,
#    'surprise': 2.8471611122691235e-05,
#    'neutral': 99.64275357978067},
#   'dominant_emotion': 'neutral',
#   'region': {'x': 153, 'y': 56, 'w': 111, 'h': 111},
#   'face_confidence': 11.060816081415396,
#   'age': 23,
#   'gender': {'Woman': 0.002923800639109686, 'Man': 99.997079372406},
#   'dominant_gender': 'Man',
#   'race': {'asian': 0.030922715086489916,
#    'indian': 4.012749344110489,
#    'black': 0.024795145145617425,
#    'white': 10.935501009225845,
#    'middle eastern': 74.32608008384705,
#    'latino hispanic': 10.669951140880585},
#   'dominant_race': 'middle eastern'}]

# %%
pre1=pre[0]

# %%
fc = cv2.CascadeClassifier(cv2.data.haarcascades+'haarcascade_frontalface_default.xml')

# %%
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
faces = fc.detectMultiScale(gray,1.1,4)
#drawing rectangle around the face
for(x,y,w,h) in faces:
    cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,0),2)

# %%
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
font = cv2.FONT_HERSHEY_SIMPLEX

cv2.putText(img,pre1['dominant_emotion'],(0,50),font,1,(255,0,0),2,cv2.LINE_4)
# Out:
# array([[[ 73,  85, 117],
#         [ 73,  85, 117],
#         [ 74,  86, 118],
#         ...,
#         [ 87,  96, 124],
#         [ 86,  95, 123],
#         [ 86,  95, 123]],
#
#        [[ 73,  85, 117],
#         [ 73,  85, 117],
#         [ 74,  86, 118],
#         ...,
#         [ 87,  96, 124],
#         [ 86,  95, 123],
#         [ 86,  95, 123]],
#
#        [[ 73,  85, 117],
#         [ 74,  86, 118],
#         [ 74,  86, 118],
#         ...,
#         [ 87,  96, 124],
#         [ 86,  95, 123],
#         [ 86,  95, 123]],
#
#        ...,
#
#        [[  0,   0,   0],
#         [254, 254, 254],
#         [254, 254, 254],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[  0,   0,   0],
#         [254, 254, 254],
#         [254, 254, 254],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[  0,   0,   0],
#         [254, 254, 254],
#         [254, 254, 254],
# ...

# %%
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
img = cv2.imread('anger_face.jpg') #anger

# %%
plt.imshow(img)

# %%
pre = DeepFace.analyze(img)
# Out:
# Action: race: 100%|██████████████████████████████████████████████████████████████████████| 4/4 [00:02<00:00,  1.75it/s]

# %%
pre
# Out:
# [{'emotion': {'angry': 46.27941593177129,
#    'disgust': 1.1981735774070266e-05,
#    'fear': 0.6542620866135256,
#    'happy': 0.0008637160924909079,
#    'sad': 38.86175288417901,
#    'surprise': 2.1382908537179368e-05,
#    'neutral': 14.20366594747711},
#   'dominant_emotion': 'angry',
#   'region': {'x': 65, 'y': 103, 'w': 180, 'h': 180},
#   'face_confidence': 9.824158996692859,
#   'age': 30,
#   'gender': {'Woman': 0.04512715095188469, 'Man': 99.95487332344055},
#   'dominant_gender': 'Man',
#   'race': {'asian': 0.06282069953158498,
#    'indian': 0.1365476637147367,
#    'black': 0.006122099148342386,
#    'white': 79.21709418296814,
#    'middle eastern': 8.457960933446884,
#    'latino hispanic': 12.119458615779877},
#   'dominant_race': 'white'}]

# %%
pre1=pre[0]

# %%
fc = cv2.CascadeClassifier(cv2.data.haarcascades+'haarcascade_frontalface_default.xml')

# %%
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
faces = fc.detectMultiScale(gray,1.1,4)
#drawing rectangle around the face
for(x,y,w,h) in faces:
    cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,0),2)

# %%
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
font = cv2.FONT_HERSHEY_SIMPLEX

cv2.putText(img,pre1['dominant_emotion'],(0,50),font,1,(255,0,0),2,cv2.LINE_4)
# Out:
# array([[[245, 245, 245],
#         [243, 244, 242],
#         [244, 245, 241],
#         ...,
#         [240, 239, 235],
#         [240, 239, 235],
#         [239, 238, 234]],
#
#        [[243, 243, 243],
#         [243, 244, 242],
#         [245, 246, 242],
#         ...,
#         [241, 240, 236],
#         [240, 239, 235],
#         [240, 239, 235]],
#
#        [[241, 244, 242],
#         [244, 245, 243],
#         [243, 244, 242],
#         ...,
#         [240, 239, 235],
#         [243, 240, 236],
#         [242, 239, 235]],
#
#        ...,
#
#        [[ 19,  19,  19],
#         [ 21,  21,  21],
#         [ 27,  27,  27],
#         ...,
#         [ 20,  19,  15],
#         [ 18,  17,  13],
#         [ 15,  14,  10]],
#
#        [[ 20,  20,  20],
#         [ 21,  21,  21],
#         [ 26,  27,  25],
#         ...,
#         [ 19,  18,  14],
#         [ 21,  18,  14],
#         [ 17,  13,  12]],
#
#        [[ 20,  20,  20],
#         [ 21,  21,  21],
#         [ 27,  28,  26],
# ...

# %%
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
img = cv2.imread('cry_face.jpg') #cry

# %%
plt.imshow(img)

# %%
pre = DeepFace.analyze(img)
# Out:
# Action: race: 100%|██████████████████████████████████████████████████████████████████████| 4/4 [00:02<00:00,  1.74it/s]

# %%
pre
# Out:
# [{'emotion': {'angry': 3.5186970206244444e-05,
#    'disgust': 9.103189893613837e-08,
#    'fear': 2.266796613308938e-05,
#    'happy': 99.88641740245612,
#    'sad': 0.0947590979010197,
#    'surprise': 2.725465329435487e-15,
#    'neutral': 0.018759555624590144},
#   'dominant_emotion': 'happy',
#   'region': {'x': 231, 'y': 80, 'w': 253, 'h': 253},
#   'face_confidence': 3.322939020988997,
#   'age': 31,
#   'gender': {'Woman': 5.582241341471672, 'Man': 94.41775679588318},
#   'dominant_gender': 'Man',
#   'race': {'asian': 73.09440970420837,
#    'indian': 0.036498092231340706,
#    'black': 0.009285765554523095,
#    'white': 25.92637836933136,
#    'middle eastern': 0.17317967722192407,
#    'latino hispanic': 0.7602518890053034},
#   'dominant_race': 'asian'}]

# %%
pre1=pre[0]

# %%
fc = cv2.CascadeClassifier(cv2.data.haarcascades+'haarcascade_frontalface_default.xml')

# %%
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
faces = fc.detectMultiScale(gray,1.1,4)
#drawing rectangle around the face
for(x,y,w,h) in faces:
    cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,0),2)

# %%
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
font = cv2.FONT_HERSHEY_SIMPLEX

cv2.putText(img,pre1['dominant_emotion'],(0,50),font,1,(255,0,0),2,cv2.LINE_4)
# Out:
# array([[[ 84,  57,   1],
#         [ 84,  57,   1],
#         [ 84,  57,   1],
#         ...,
#         [111,  83,   0],
#         [111,  83,   0],
#         [111,  83,   0]],
#
#        [[ 84,  57,   1],
#         [ 84,  57,   1],
#         [ 84,  57,   1],
#         ...,
#         [111,  83,   0],
#         [111,  83,   0],
#         [111,  83,   0]],
#
#        [[ 84,  57,   1],
#         [ 84,  57,   1],
#         [ 84,  57,   1],
#         ...,
#         [111,  83,   0],
#         [111,  83,   0],
#         [111,  83,   0]],
#
#        ...,
#
#        [[100,  75,   1],
#         [100,  75,   1],
#         [100,  75,   1],
#         ...,
#         [114,  85,   0],
#         [114,  85,   0],
#         [114,  85,   0]],
#
#        [[100,  75,   1],
#         [100,  75,   1],
#         [100,  75,   1],
#         ...,
#         [114,  85,   0],
#         [114,  85,   0],
#         [114,  85,   0]],
#
#        [[100,  75,   1],
#         [100,  75,   1],
#         [100,  75,   1],
# ...

# %%
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
import cv2
from deepface import DeepFace

model = DeepFace.build_model("Emotion")

emotion_labels = ['happy', 'sad', 'fear', 'normal', 'sad', 'surprise', 'neutral']

# Load face cascade classifier
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

cap = cv2.VideoCapture(0)

while True:
    # Capture frame-by-frame
    ret, frame = cap.read()

    # Convert frame to grayscale
    gray_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    # Detect faces in the frame
    faces = face_cascade.detectMultiScale(gray_frame, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))

    for (x, y, w, h) in faces:
        # Extract the face-Region of Interest
        face_roi = gray_frame[y:y + h, x:x + w]

        # Resize the face ROI to match the input shape of the model
        resized_face = cv2.resize(face_roi, (48, 48), interpolation=cv2.INTER_AREA)

        # Normalize the resized face image
        normalized_face = resized_face / 255.0

       
        reshaped_face = normalized_face.reshape(1, 48, 48, 1)

        # Predict emotions using the pre-trained model
        preds = model.predict(reshaped_face)[0]
        emotion_idx = preds.argmax()
        emotion = emotion_labels[emotion_idx]

        # Drawing rectangle around face and label with predicted emotion
        cv2.rectangle(frame, (x, y), (x + w, y + h), (0, 255, 0), 2)
        cv2.putText(frame, emotion, (x, y - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (255, 0, 0), 2)

    # Display the resulting frame
    cv2.imshow('Real-time Emotion Detection', frame)

    # Press 'q' to exit
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the capture and close all windows
cap.release()
cv2.destroyAllWindows()
# Out:
# ...
# 1/1 [==============================] - 0s 52ms/step
